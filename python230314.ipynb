# %% [markdown]
# # 대분류

# %% [markdown]
# ## 파이썬기초문법
# - 주석처리
# - 여러 줄 주석처리 시,
#   + 함수, 클래스 작성할 때
# 요긴하게 쓰임 ( 예 : Docstring)

# %%
# 이 코드는 어떤 코드임

'''
여러줄 주석처리
'''

"""
여러줄 주석처리
"""

print("Hello World") # 중간 주석
# Out:
# Hello World

# %% [markdown]
# ## 변수의 종류 (Scala 자료형)
# - 크게 4가지 존재 : int, float, bool, None
# - 스칼라의 의미 : 더 이상 나누어지지 않는 것

# %% [markdown]
# ### int형 예제

# %%
temp_int = 1
print(temp_int) 
print(type(temp_int))
# Out:
# 1
# <class 'int'>

# %% [markdown]
# - 문자열

# %%
temp_int = '1'
print(temp_int)
print(type(temp_int))
# Out:
# 1
# <class 'str'>

# %% [markdown]
# ### float형 예제
# - 실수형

# %%
num_float = 0.2
print(num_float)
print(type(num_float))
# Out:
# 0.2
# <class 'float'>

# %% [markdown]
# ### Bool 형
# - 참 거짓

# %%
temp_bool = True
temp_bool = False

print(type(temp_bool))
# Out:
# <class 'bool'>

# %% [markdown]
# ### None 자료형
# - Null을 나타내는 자료형
#  + 데이터 분석에서 가장 처리하기 까다로운 자료형형

# %%
temp_none = None
print(type(temp_none))
# Out:
# <class 'NoneType'>

# %% [markdown]
# ## 사칙연산
# - 정수형 사칙연산

# %%
a = 3
b = 2

print(a + b)  # 덧셈
print(a - b)  # 뺄셈
print(a * b)  # 곱셈
print(a / b)  # 나누기 : 항상 실수형태로 출력됨
print(a // b) # 몫
print(a ** b) # a의 b 승승
print(a % b) # 나머지
# Out:
# 5
# 1
# 6
# 1.5
# 1
# 9
# 1

# %% [markdown]
# ### 실수형 사칙연산

# %%
a = 6.0
b = 2.0

print(a + b)  # 덧셈
print(a - b)  # 뺄셈
print(a * b)  # 곱셈
print(a / b)  # 나누기 : 항상 실수형태로 출력됨
print(a // b) # 몫
print(a ** b) # a의 b승승
print(a % b) # 나머지
# Out:
# 8.0
# 4.0
# 12.0
# 3.0
# 3.0
# 36.0
# 0.0

# %% [markdown]
# ### 논리형 연산자
# - AND 조건, OR 조건이 있음음

# %%
print(True and True)
print(True and False)
print(False and True)
print(False and False)
# Out:
# True
# False
# False
# False

# %%
print(True or True)
print(True or False)
print(False or True)
print(False or False)
# Out:
# True
# True
# True
# False

# %% [markdown]
# ### 비교 연산자
# - 비교 연산자는 부등호를 의미함
# - 왼쪽이 기준 값값

# %%
print(4 > 3)
print(3 > 4)
print(3 >= 4)
print(3 <= 4)
# Out:
# True
# False
# False
# True

# %% [markdown]
# ## input()
# - print() : 출력
# - input() : 입력

# %%
var = input("값을 입력해주세요!! ")

int_var = int(var)
print(int_var)
print(type(int_var))
# Out:
# 값을 입력해주세요!! 5
# 5
# <class 'int'>

# %%
num1 = int(input("값을 입력해주세요!! "))
num2 = int(input("값을 입력해주세요!! "))

result = num1 + num2
print(result)
# Out:
# 값을 입력해주세요!! 123
# 값을 입력해주세요!! 456
# 579

# %% [markdown]
# ## String
# - 매우 중요함!!!

# %% [markdown]
# ### String 연산자

# %%
str1 = "Hello "
str2 = "World"

result = str1 + str2
print(result)
# Out:
# Hello World

# %%
str1 = "55"
str2 = "1000"

print(int(str1) + int(str2))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-49-0e8d0e56f081> in <module>
#       1 str1 = "55"
#       2 str2 = "1000"
# ----> 3 print(int(str1) + int(str2))
#
# TypeError: 'str' object is not callable

# %% [markdown]
# - 곱셈 연산자 사용

# %%
greeting = "Hello World "
print(greeting * 3)
# Out:
# Hello World Hello World Hello World

# %% [markdown]
# ### Indexing
# - 중요!!
# - 0번째 부터 시작

# %%
greeting = "Hello World!"
print(greeting[-2])
# Out:
# d

# %% [markdown]
# ### 슬라이싱
# - 자름

# %%
greeting = "Hello World!"
print(greeting[0:5])
print(greeting[:])
print(greeting[6:])
print(greeting[3:9])
print(greeting[5:-1])
print(greeting[0:9:2])
# Out:
# Hello
# Hello World!
# World!
# lo Wor
#  World
# HloWr

# %%
greeting = "Hello World!!!!"
greeting[13]
# Out:
# '!'

# %% [markdown]
# ### 문자열의 함수들
# - 공식문서!

# %% [markdown]
# # 문자열 자료형

# %% [markdown]
# ## 문자열이란?

# %%
"Life is too short, You need Python"
"a"
"123"
# Out:
# 'Life is too short, You need Python'

# %% [markdown]
# ## 문자열은 어떻게 만들고 사용할까?

# %% [markdown]
# ### 1. 큰 따옴표(")로 양쪽 둘러싸기

# %%
"Hello World"
# Out:
# 'Hello World'

# %% [markdown]
# ### 2. 작은따옴표(')로 양쪽 둘러싸기기

# %%
'Python is fun'

# %% [markdown]
# ### 3. 큰따옴표 3개를 연속(""")으로 써서 양쪽 둘러싸기기

# %%
"""Life is too short, You need python"""

# %% [markdown]
# ## 문자열 안에 작은따옴표나 큰따옴표를 포함시키고 싶을 때

# %% [markdown]
# ### 1. 문자열에 작은따옴표(') 포함시키기

# %%
food = "Python's favorite food is prel"
food
# Out:
# "Python's favorite food is prel"

# %%
food = 'Python's favorite food is prel'
File "<stdin>", line 1
# Out:
#   File "<ipython-input-8-ab3c74acfe22>", line 1
#     food = 'Python's favorite food is prel'
#                    ^
# SyntaxError: invalid syntax

# %% [markdown]
# ### 2. 문자열에 큰따옴표(") 포함시키기

# %%
say = '"Python is very easy."he says.'

# %% [markdown]
# ### 3. 백슬래시(\)를 사용해서 작은따옴표(')와 큰따옴표(")를 문자열에 포함시키기

# %%
food = 'Python\'s favorite food is perl'
say = "\"Python is very easy.\" he says."

# %% [markdown]
# ## 여러 줄인 문자열을 변수에 대입하고 싶을 때

# %% [markdown]
# ### 1. 줄을 바꾸기 위한 이스케이프 코드 \n 삽입하기

# %%
multiline = "Life is too short\nYou need python"
print(multiline)
# Out:
# Life is too short
# You need python

# %% [markdown]
# ### 2. 연속된 작은따옴표 3개(''') 또는 큰따옴표 3개(""") 사용하기

# %%
multiline='''
 Life is too short
 You need pythhon
'''
print(multiline)
# Out:
#  Life is too short
#  You need pythhon

# %%
multiline="""
Life is too short
You need python
"""
print(multiline)
# Out:
# Life is too short
# You need python

# %% [markdown]
# ## 이스케이프 코드란?

# %% [markdown]
# - \n : 문자열 안에서 줄을 바꿀 때 사용
# - \t : 문자열 사이에 탭 간격을 줄 때 사용
# - \\ : 문자 \를 그대로 표현할 때 사용
# - \' : 작은따옴표(')를 그대로 표현할 때 사용
# - \" : 큰따옴표(")를 그대로 표현할 때 사용
# - \r : 캐리지 리턴(줄 바꿈 문자, 현재 커서를 가장 앞으로 이동)
# - \f : 폼피드(줄 바꿈 문자, 현재 커서를 다음 줄로 이동)
# - \a : 벨 소리(출력할 때 PC스피커에서 '삑'소리가 난다)
# - \b : 백 스페이스
# - \000 : 널 문자

# %% [markdown]
# ## 문자열 연산하기

# %% [markdown]
# ### 문자열 더해서 연결하기(Concatenation)

# %%
head = "Python"
tail = " is fun!"
head + tail
# Out:
# 'Python is fun!'

# %% [markdown]
# ### 문자열 곱하기

# %%
a = "python"
a * 2
# Out:
# 'pythonpython'

# %% [markdown]
# ### 문자열 곱하기 응용

# %%
print("=" * 50)
print("My Program")
print("=" * 50)
# Out:
# ==================================================
# My Program
# ==================================================

# %% [markdown]
# ### 문자열 길이 구하기

# %%
a = "Life is too short"
len(a)
# Out:
# 17

# %% [markdown]
# ## 문자열 인덱싱과 슬라이싱

# %% [markdown]
# ### 문자열 인덱싱이란?

# %%
a = "Life is too short, You need Python"
a[3]
# Out:
# 'e'

# %% [markdown]
# ### 문자열 인덱싱 활용하기

# %%
a = "Life is too short, You need Python"
print(a[0])
print(a[12])
print(a[-1])
# Out:
# L
# s
# n

# %% [markdown]
# ### 문자열 슬라이싱이란?

# %%
a = "Life is too short, You need Python"
b = a[0] + a[1] + a[2] + a[3]
b
# Out:
# 'Life'

# %%
a = "Life is too short, You need Python"
print(a[0:4])
print(a[0:3])
# Out:
# Life
# Lif

# %% [markdown]
# ### 문자열을 슬라이싱하는 방법

# %%
a = "Life is too short, You need Python"
print(a[0:5])
print(a[0:2])
print(a[5:7])
print(a[12:17])
print(a[19:])
print(a[:17])
print(a[:])
print(a[19:-7])
# Out:
# Life
# Li
# is
# short
# You need Python
# Life is too short
# Life is too short, You need Python
# You need

# %% [markdown]
# ### 슬라이싱으로 문자열 나누기

# %%
a = "20010331Rainy"
date = a[:8]
weather = a[8:]
print(date)
print(weather)
# Out:
# 20010331
# Rainy

# %%
a = "20010331Rainy"
year = a[:4]
day = a[4:8]
weather = a[8:]
print(year)
print(day)
print(weather)
# Out:
# 2001
# 0331
# Rainy

# %% [markdown]
# #### ["Pithon"이라는 문자열을 "Python"으로 바꾸려면?]

# %%
a = "Pithon"
print(a[1])
a[1] = 'y'
# Out:
# i
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-1-60dee05f070c> in <module>
#       1 a = "Pithon"
#       2 print(a[1])
# ----> 3 a[1] = 'y'
#
# TypeError: 'str' object does not support item assignment

# %%
a = "Pithon"
print(a[:1])
print(a[2:])
print(a[:1] + 'y' + a[2:])
# Out:
# P
# thon
# Python

# %% [markdown]
# ## 문자열 포매팅

# %% [markdown]
# ### 문자열 포매팅 따라 하기

# %% [markdown]
# #### 1.숫자 바로 대입

# %%
"I eat %d apples."% 3
# Out:
# 'I eat 3 apples.'

# %% [markdown]
# #### 2.문자열 바로대입

# %%
"I eat %s apples." % "five"
# Out:
# 'I eat five apples.'

# %% [markdown]
# #### 3.숫자 값을 나타내는 변수로 대입

# %%
number = 3
"I eat %d apples." % number
# Out:
# 'I eat 3 apples.'

# %% [markdown]
# #### 2개 이상의 값 넣기

# %%
number = 10
day = "three"
"I ate %d apples. so I was sick for %s days." % (number, day)
# Out:
# 'I ate 10 apples. so I was sick for three days.'

# %% [markdown]
# ### 문자열 포맷코드
# - %s : 문자열(String)
# - %c : 문자 1개(character)
# - %d : 정수(Integer)
# - %f : 부동소수(floating-point)
# - %o : 8진수
# - %x : 16진수
# - %% : Literal % (문자 % 자체)

# %%
print("I have %s apples" % 3)
print("rate is %s" % 3.234)
# Out:
# I have 3 apples
# rate is 3.234

# %% [markdown]
# ### [포매팅 연산자 %d와 %를 같이 쓸 때는 %%를 쓴다]

# %%
"Error is %d%." % 98
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-061de263c4b7> in <module>
# ----> 1 "Error is %d%." % 98
#
# ValueError: incomplete format

# %%
"Error is %d%%." % 98
# Out:
# 'Error is 98%.'

# %% [markdown]
# ### 포맷코드와 숫자 함께 사용하기

# %% [markdown]
# #### 1.정렬과 공백

# %%
"%10s" % "hi"
# Out:
# '        hi'
